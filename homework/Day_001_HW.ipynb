# %% [markdown]
# # 作業1
# ### Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

# %% [markdown]
# 1. 你選的這組資料為何重要<br>
# &emsp;我選擇的資料是[Heart Disease UCI](https://www.kaggle.com/ronitf/heart-disease-uci)，
# 心臟是人體最重要的器官之一，很多疾病都與心臟有關，所以透過分析可以提早預防疾病的發生。<br>

# %% [markdown]
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
# &emsp;資料的提供者共有4位: <br>
# 1.Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D. <br>
# 2.University Hospital, Zurich, Switzerland: William Steinbrunn, M.D. <br>
# 3.University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D. <br>
# 4.V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.<br>

# %% [markdown]
# 3. 蒐集而來的資料型態為何 <br>
# &emsp;資料為csv檔，資料一共有14個變數包含(年齡、性別等等)皆為數字，而變數target為lable(1 = 有心臟病，0 = 無心臟病)。

# %% [markdown]
# 4. 這組資料想解決的問題如何評估 <br>
# &emsp;為了防止心臟病的發生，可以透過該資料找出可能導致有心臟病的變數為何。

# %% [markdown]
# # 作業2
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的<br>分析/解決方案：

# %% [markdown]
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br>
# &emsp;想要提升業績就是減少空車等待的時間，透過離、尖峰時段派出車輛多寡，或是在客人最常搭車的地方等待。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集) <br>
# &emsp;假如使用APP叫車則可從後端將資料取出，若是路上攔車者只能使用問卷方式取得資料。
# 3. 蒐集而來的資料型態為何 <br>
# &emsp;非結構化資料
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證) <br>
# &emsp;驗證空車等待時間是否有縮短及尖、離峰的派出的車輛是否合理。

# %% [markdown]
# # 作業3
# ## 請寫一個函式用來計算Mean Square Error
# $MSE = \frac{1}{n}\sum^n_{i=1}(Y_i - \hat Y_t)^2$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.841

# %%
def mean_squared_error(y,yt):
    MSE = sum((y - yt)**2) / len(y)
    return(MSE)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 180.780
# The Mean absolute error is 10.683
